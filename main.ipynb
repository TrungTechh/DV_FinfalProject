# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the data from the csv file

# %%
# read csv
df = pd.read_csv('Life_Expectancy_Data.csv')

# %% [markdown]
# ### About the data

# %% [markdown]
# The Global Health Observatory (GHO) data repository under World Health Organization (WHO) keeps track of the health status as well as many other related factors for all countries The datasets are made available to public for the purpose of health data analysis. The dataset related to life expectancy, health factors for 193 countries has been collected from the same WHO data repository website and its corresponding economic data was collected from United Nation website. Among all categories of health-related factors only those critical factors were chosen which are more representative. It has been observed that in the past 15 years , there has been a huge development in health sector resulting in improvement of human mortality rates especially in the developing nations in comparison to the past 30 years.

# %% [markdown]
# #### Feature information
#
# | Heeader name                    | Description |
# | ------------------------------- | ----------- |
# | Country                         |             |
# | Year                            |             |
# | Status                          |             |
# | Life expectancy                 |             |
# | Adult Mortality                 |             |
# | infant deaths                   |             |
# | Alcohol                         |             |
# | percentage expenditure          |             |
# | Hepatitis B                     |             |
# | Measles                         |             |
# | BMI                             |             |
# | under-five deaths               |             |
# | Polio                           |             |
# | Total expenditure               |             |
# | Diphtheria                      |             |
# | HIV/AIDS                        |             |
# | GDP                             |             |
# | Population                      |             |
# | thinness 1-19 years             |             |
# | thinness 5-9 years              |             |
# | Income composition of resources |             |
# | Schooling                       |             |

# %%
# country is the

# %%
# show first 5 rows
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
# size of data
df.shape
# Out:
# (2938, 22)

# %% [markdown]
# #### Number of rows and columns of the DataFrame

# %%
# get number of rows
num_rows = df.shape[0]

# get number of columns
num_cols = df.shape[1]

print('Number of rows:', num_rows)
print('Number of columns:', num_cols)
# Out:
# Number of rows: 2938
# Number of columns: 22

# %% [markdown]
# #### Data types of the columns

# %%
# get DataFrame info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %% [markdown]
# #### Check duplicates rows

# %%
# get number of duplicated rows
duplicated_rows = df.duplicated().sum()

# check if there are duplicated rows
if duplicated_rows > 0:
    print("Number of duplicated rows:", duplicated_rows)
else:
    print("No duplicated rows found")
# Out:
# No duplicated rows found

# %% [markdown]
# ### Statistical

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
#  HIV/AIDS                        2938.0  1.742103e+00  5.077785e+00
# GDP                              2490.0  7.483158e+03  1.427017e+04
# Population                       2286.0  1.275338e+07  6.101210e+07
#  thinness  1-19 years            2904.0  4.839704e+00  4.420195e+00
#  thinness 5-9 years              2904.0  4.870317e+00  4.508882e+00
# Income composition of resources  2771.0  6.275511e-01  2.109036e-01
# Schooling                        2775.0  1.199279e+01  3.358920e+00
#
#                                         min            25%           50%  \
# Year                             2000.00000    2004.000000  2.008000e+03
# Life expectancy                    36.30000      63.100000  7.210000e+01
# Adult Mortality                     1.00000      74.000000  1.440000e+02
# infant deaths                       0.00000       0.000000  3.000000e+00
# Alcohol                             0.01000       0.877500  3.755000e+00
# percentage expenditure              0.00000       4.685343  6.491291e+01
# Hepatitis B                         1.00000      77.000000  9.200000e+01
# Measles                             0.00000       0.000000  1.700000e+01
#  BMI                                1.00000      19.300000  4.350000e+01
# under-five deaths                   0.00000       0.000000  4.000000e+00
# Polio                               3.00000      78.000000  9.300000e+01
# Total expenditure                   0.37000       4.260000  5.755000e+00
# Diphtheria                          2.00000      78.000000  9.300000e+01
#  HIV/AIDS                           0.10000       0.100000  1.000000e-01
# GDP                                 1.68135     463.935626  1.766948e+03
# Population                         34.00000  195793.250000  1.386542e+06
#  thinness  1-19 years               0.10000       1.600000  3.300000e+00
#  thinness 5-9 years                 0.10000       1.500000  3.300000e+00
# Income composition of resources     0.00000       0.493000  6.770000e-01
# Schooling                           0.00000      10.100000  1.230000e+01
#
#                                           75%           max
# Year                             2.012000e+03  2.015000e+03
# Life expectancy                  7.570000e+01  8.900000e+01
# Adult Mortality                  2.280000e+02  7.230000e+02
# infant deaths                    2.200000e+01  1.800000e+03
# Alcohol                          7.702500e+00  1.787000e+01
# percentage expenditure           4.415341e+02  1.947991e+04
# Hepatitis B                      9.700000e+01  9.900000e+01
# Measles                          3.602500e+02  2.121830e+05
#  BMI                             5.620000e+01  8.730000e+01
# under-five deaths                2.800000e+01  2.500000e+03
# Polio                            9.700000e+01  9.900000e+01
# Total expenditure                7.492500e+00  1.760000e+01
# Diphtheria                       9.700000e+01  9.900000e+01
#  HIV/AIDS                        8.000000e-01  5.060000e+01
# GDP                              5.910806e+03  1.191727e+05
# Population                       7.420359e+06  1.293859e+09
#  thinness  1-19 years            7.200000e+00  2.770000e+01
#  thinness 5-9 years              7.200000e+00  2.860000e+01
# Income composition of resources  7.790000e-01  9.480000e-01
# Schooling                        1.430000e+01  2.070000e+01

# %%
# get number of unique values of Country column
df['Country'].unique().size
# Out:
# 193

# %% [markdown]
# ### Handle missing values

# %%
# check missing values
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# calculate missing percentage
missing_percentage = df.isnull().mean() * 100
missing_percentage[missing_percentage.values > 0].sort_values(ascending=False)
# Out:
# Population                         22.191967
# Hepatitis B                        18.822328
# GDP                                15.248468
# Total expenditure                   7.692308
# Alcohol                             6.603131
# Income composition of resources     5.684139
# Schooling                           5.547992
#  BMI                                1.157250
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Polio                               0.646698
# Diphtheria                          0.646698
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# dtype: float64

# %%
# replacing the Null Values with mean values of the data
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,
                        strategy='mean', fill_value=None)
df['Life expectancy '] = imputer.fit_transform(df[['Life expectancy ']])
df['Adult Mortality'] = imputer.fit_transform(df[['Adult Mortality']])
df['Alcohol'] = imputer.fit_transform(df[['Alcohol']])
df['Hepatitis B'] = imputer.fit_transform(df[['Hepatitis B']])
df[' BMI '] = imputer.fit_transform(df[[' BMI ']])
df['Polio'] = imputer.fit_transform(df[['Polio']])
df['Total expenditure'] = imputer.fit_transform(df[['Total expenditure']])
df['Diphtheria '] = imputer.fit_transform(df[['Diphtheria ']])
df['GDP'] = imputer.fit_transform(df[['GDP']])
df['Population'] = imputer.fit_transform(df[['Population']])
df[' thinness  1-19 years'] = imputer.fit_transform(
    df[[' thinness  1-19 years']])
df[' thinness 5-9 years'] = imputer.fit_transform(df[[' thinness 5-9 years']])
df['Income composition of resources'] = imputer.fit_transform(
    df[['Income composition of resources']])
df['Schooling'] = imputer.fit_transform(df[['Schooling']])

# %%
# check missing values again
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# ### Correlation

# %%
% % capture
# correlation matrix
corr = df.corr()

# %%
corr.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_6dcf4_row0_col0, #T_6dcf4_row1_col1, #T_6dcf4_row2_col2, #T_6dcf4_row3_col3, #T_6dcf4_row3_col9, #T_6dcf4_row4_col4, #T_6dcf4_row5_col5, #T_6dcf4_row6_col6, #T_6dcf4_row7_col7, #T_6dcf4_row8_col8, #T_6dcf4_row9_col3, #T_6dcf4_row9_col9, #T_6dcf4_row10_col10, #T_6dcf4_row11_col11, #T_6dcf4_row12_col12, #T_6dcf4_row13_col13, #T_6dcf4_row14_col14, #T_6dcf4_row15_col15, #T_6dcf4_row16_col16, #T_6dcf4_row17_col17, #T_6dcf4_row18_col18, #T_6dcf4_row19_col19 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_6dcf4_row0_col1, #T_6dcf4_row19_col5 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_6dcf4_row0_col2, #T_6dcf4_row14_col10 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_6dcf4_row0_col3, #T_6dcf4_row19_col2 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_6dcf4_row0_col4, #T_6dcf4_row7_col4, #T_6dcf4_row13_col4 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_6dcf4_row0_col5 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_6dcf4_row0_col6 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_6dcf4_row0_col7, #T_6dcf4_row1_col15, #T_6dcf4_row3_col10, #T_6dcf4_row3_col12, #T_6dcf4_row4_col0, #T_6dcf4_row4_col16, #T_6dcf4_row5_col15, #T_6dcf4_row7_col6, #T_6dcf4_row11_col3, #T_6dcf4_row12_col15, #T_6dcf4_row13_col15, #T_6dcf4_row14_col15, #T_6dcf4_row16_col0, #T_6dcf4_row17_col0, #T_6dcf4_row18_col16 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_6dcf4_row0_col8 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_6dcf4_row0_col9, #T_6dcf4_row2_col4, #T_6dcf4_row7_col5, #T_6dcf4_row13_col19 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_6dcf4_row0_col10, #T_6dcf4_row15_col19 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_6dcf4_row0_col11, #T_6dcf4_row6_col16, #T_6dcf4_row6_col17, #T_6dcf4_row9_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_6dcf4_row0_col12, #T_6dcf4_row0_col17, #T_6dcf4_row7_col1, #T_6dcf4_row10_col5, #T_6dcf4_row10_col11, #T_6dcf4_row11_col10 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_6dcf4_row0_col13, #T_6dcf4_row2_col9, #T_6dcf4_row5_col2, #T_6dcf4_row6_col14 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_6dcf4_row0_col14, #T_6dcf4_row6_col13 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_6dcf4_row0_col15, #T_6dcf4_row13_col14 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_6dcf4_row0_col16, #T_6dcf4_row12_col5 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_6dcf4_row0_col18 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_6dcf4_row0_col19, #T_6dcf4_row4_col11, #T_6dcf4_row12_col4 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_6dcf4_row1_col0, #T_6dcf4_row8_col6, #T_6dcf4_row14_col13, #T_6dcf4_row15_col4 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_6dcf4_row1_col2, #T_6dcf4_row1_col13, #T_6dcf4_row2_col1, #T_6dcf4_row2_col10, #T_6dcf4_row2_col12, #T_6dcf4_row2_col14, #T_6dcf4_row2_col18, #T_6dcf4_row6_col15, #T_6dcf4_row8_col3, #T_6dcf4_row8_col7, #T_6dcf4_row8_col9, #T_6dcf4_row8_col16, #T_6dcf4_row8_col17, #T_6dcf4_row9_col6, #T_6dcf4_row13_col0, #T_6dcf4_row16_col4, #T_6dcf4_row16_col5, #T_6dcf4_row16_col19, #T_6dcf4_row17_col5, #T_6dcf4_row17_col8, #T_6dcf4_row17_col11, #T_6dcf4_row17_col14 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_6dcf4_row1_col3, #T_6dcf4_row19_col9 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_6dcf4_row1_col4, #T_6dcf4_row17_col9 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_6dcf4_row1_col5, #T_6dcf4_row18_col5, #T_6dcf4_row18_col12 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_6dcf4_row1_col6, #T_6dcf4_row4_col13, #T_6dcf4_row5_col12 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_6dcf4_row1_col7, #T_6dcf4_row1_col9 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_6dcf4_row1_col8 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_6dcf4_row1_col10, #T_6dcf4_row3_col7, #T_6dcf4_row5_col19, #T_6dcf4_row10_col19, #T_6dcf4_row12_col6 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_6dcf4_row1_col11, #T_6dcf4_row4_col10, #T_6dcf4_row9_col13 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_6dcf4_row1_col12, #T_6dcf4_row16_col2, #T_6dcf4_row18_col4 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_6dcf4_row1_col14, #T_6dcf4_row10_col18, #T_6dcf4_row19_col14 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_6dcf4_row1_col16, #T_6dcf4_row6_col3, #T_6dcf4_row6_col9, #T_6dcf4_row8_col15, #T_6dcf4_row10_col3, #T_6dcf4_row10_col9, #T_6dcf4_row12_col3, #T_6dcf4_row16_col10, #T_6dcf4_row17_col10, #T_6dcf4_row17_col12, #T_6dcf4_row19_col7 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_6dcf4_row1_col17, #T_6dcf4_row7_col0 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_6dcf4_row1_col18 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_6dcf4_row1_col19 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_6dcf4_row2_col0, #T_6dcf4_row18_col7 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_6dcf4_row2_col3, #T_6dcf4_row10_col2, #T_6dcf4_row12_col2, #T_6dcf4_row14_col2 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_6dcf4_row2_col5, #T_6dcf4_row2_col19, #T_6dcf4_row3_col6, #T_6dcf4_row16_col8, #T_6dcf4_row16_col11, #T_6dcf4_row16_col14, #T_6dcf4_row17_col4, #T_6dcf4_row17_col19 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_6dcf4_row2_col6, #T_6dcf4_row11_col15, #T_6dcf4_row16_col12 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_6dcf4_row2_col7, #T_6dcf4_row3_col19, #T_6dcf4_row13_col7 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_6dcf4_row2_col8, #T_6dcf4_row4_col9, #T_6dcf4_row7_col12, #T_6dcf4_row14_col9 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_6dcf4_row2_col11 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_6dcf4_row2_col13 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_6dcf4_row2_col15, #T_6dcf4_row3_col0, #T_6dcf4_row4_col17, #T_6dcf4_row9_col0, #T_6dcf4_row11_col9, #T_6dcf4_row13_col1, #T_6dcf4_row13_col10, #T_6dcf4_row13_col12 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_6dcf4_row2_col16 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_6dcf4_row2_col17 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_6dcf4_row3_col1, #T_6dcf4_row5_col13 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_6dcf4_row3_col2 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_6dcf4_row3_col4, #T_6dcf4_row6_col5, #T_6dcf4_row13_col11 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_6dcf4_row3_col5, #T_6dcf4_row3_col14, #T_6dcf4_row7_col11, #T_6dcf4_row13_col18, #T_6dcf4_row15_col0, #T_6dcf4_row17_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_6dcf4_row3_col8, #T_6dcf4_row6_col0, #T_6dcf4_row8_col13 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_6dcf4_row3_col11, #T_6dcf4_row5_col3, #T_6dcf4_row9_col11 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_6dcf4_row3_col13 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_6dcf4_row3_col15, #T_6dcf4_row7_col3, #T_6dcf4_row17_col2 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_6dcf4_row3_col16 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_6dcf4_row3_col17, #T_6dcf4_row8_col19, #T_6dcf4_row9_col17 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_6dcf4_row3_col18, #T_6dcf4_row10_col0, #T_6dcf4_row10_col16, #T_6dcf4_row10_col17, #T_6dcf4_row12_col17, #T_6dcf4_row13_col3, #T_6dcf4_row14_col0 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_6dcf4_row4_col1 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_6dcf4_row4_col2, #T_6dcf4_row15_col18, #T_6dcf4_row19_col6 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_6dcf4_row4_col3, #T_6dcf4_row14_col7, #T_6dcf4_row18_col15, #T_6dcf4_row18_col17 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_6dcf4_row4_col5 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_6dcf4_row4_col6 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_6dcf4_row4_col7, #T_6dcf4_row7_col10 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_6dcf4_row4_col8 {
#   background-color: #5db96b;
#   color: #f1f1f1

# %%
# histogram of Life expectancy
df['Life expectancy '].hist(bins=50, figsize=(
    12, 5), color='#86bf91', grid=False, zorder=2, rwidth=0.9)
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Comment:

# %% [markdown]
# References: https://www.kaggle.com/code/varunsaikanuri/life-expectancy-visualization
